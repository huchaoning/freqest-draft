# %%
from src import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src import *
#
# File c:\Users\Administrator\Desktop\freqest\src\__init__.py:1
# ----> 1 from .core import *
#       2 from .estimator import *
#
# File c:\Users\Administrator\Desktop\freqest\src\core.py:7
#       4 from datetime import datetime, timedelta, timezone
#       6 from .estimator import freq_estimator
# ----> 7 from .api import *
#      10 __all__ = [
#      11     'qCMOS',
#      12     'DMD',
#    (...)
#      15     'DI',
#      16 ]
#      19 ####################
#      20 #    Equipments    #
#      21 ####################
#
# File c:\Users\Administrator\Desktop\freqest\src\api\__init__.py:2
#       1 from .ALP4 import *
# ----> 2 from .dcam import *
#
# File c:\Users\Administrator\Desktop\freqest\src\api\dcam.py:7
#       1 # dcam.py : Jun 30, 2021
#       2 #
# ...
