# %%
from myutils import imshow
import matplotlib.pyplot as plt
plt.rcdefaults()
from src import *

# %%
plt.rcParams['xtick.minor.visible'] = 'False'
plt.rcParams['ytick.minor.visible'] = 'False'

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath, amssymb, physics, microtype}'

# %%
i=21
title = np.load(r'D:\freqest\result\expt\noisy\spade_5px.npz')['b'][i]
imshow(qCMOS.convert2photons(np.load('raw/noisy/frame0/frames.npz')['spade'][i].astype(float)), 
       title=rf'$b/\nu\approx{np.round(title, 4)}$', save=f'raw/noisy/spade_{i}.svg', override=True)
plt.show()

title = np.load(r'D:\freqest\result\expt\noisy\di_5px.npz')['b'][i]
imshow(qCMOS.convert2photons(np.load('raw/noisy/frame0/frames.npz')['di'][i].astype(float)), 
       title=rf'$b/\nu\approx{np.round(title, 4)}$', save=f'raw/noisy/di_{i}.svg', override=True)
plt.show()
