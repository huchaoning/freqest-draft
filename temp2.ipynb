# %%
from src import *
from myutils import *

# %%
freq_list = np.linspace(0.1, 0.4, 61)

# %%
def f():
    for _f in tqdm(freq_list):
        f = np.round(_f, 5)

        raw = np.load(rf'__raw__/spade_5px/spade_{f}_raw.npy')
        timestamp = np.load(rf'__raw__/spade_5px/spade_{f}_timestamp.npy')

        meta = MetaData('SPADE', f, 5*DMD.PIXEL_SIZE/2, timestamp)

        c = FrequencyEstimation.FromRaw(raw, meta)
        c.savez(rf'__estimates__/spade_5px/spade_{f}.npz')

f()
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]d:\freqest - beta\src\estimator.py:81: RuntimeWarning: invalid value encountered in log
#   return lambda params: - data.T @ np.log(_p(axis, *params)) / data.sum()
#   0%|          | 0/61 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 13
#      10         c = FrequencyEstimation.FromRaw(raw, meta)
#      11         c.savez(rf'__estimates__/spade_5px/spade_{f}.npz')
# ---> 13 f()
#
# Cell In[3], line 10, in f()
#       6 timestamp = np.load(rf'__raw__/spade_5px/spade_{f}_timestamp.npy')
#       8 meta = MetaData('SPADE', f, 5*DMD.PIXEL_SIZE/2, timestamp)
# ---> 10 c = FrequencyEstimation.FromRaw(raw, meta)
#      11 c.savez(rf'__estimates__/spade_5px/spade_{f}.npz')
#
# File d:\freqest - beta\src\core.py:168, in FrequencyEstimation.FromRaw(cls, raw, metadata)
#     165 else:
#     166     raise ValueError
# --> 168 expt.est_all()
#     169 return Estimates(frequency_estimates = expt.lse,
#     170
#     171                  cropped_data = expt.cropped,
#    (...)
#     177
#     178                  metadata = metadata)
#
# File d:\freqest - beta\src\core.py:68, in _Share.est_all(self)
#      66 self.pn = self.cropped.sum(-1)
#      67 self.w = _relu(self.noise / self.cropped.mean(-1))
# ---> 68 self.td = td_estimator(self.__class__.__name__, self.cropped)
#      69 self.lse = np.array([freq_estimator(sample) for sample in self.td])
#
# File d:\freqest - beta\src\estimator.py:92, in td_estimator(measurement, sample, method)
#      89         else:
#      90             raise RuntimeError('not converged')
# ---> 92     time_domain = [_run_mle(flatten_data[i]) for i in range(works)]
#      94 return np.array(time_domain).reshape(*origin_shape[:-1])
#
# File d:\freqest - beta\src\estimator.py:92, in <listcomp>(.0)
#      89         else:
#      90             raise RuntimeError('not converged')
# ---> 92     time_domain = [_run_mle(flatten_data[i]) for i in range(works)]
#      94 return np.array(time_domain).reshape(*origin_shape[:-1])
#
# File d:\freqest - beta\src\estimator.py:90, in td_estimator.<locals>._run_mle(data)
#      88     return result.x[0]
#      89 else:
# ---> 90     raise RuntimeError('not converged')
#
# RuntimeError: not converged
